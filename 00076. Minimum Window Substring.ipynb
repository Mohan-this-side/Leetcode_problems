# %% [markdown]
# Given two strings s and t of lengths m and n respectively, return the minimum window
# substring
#  of s such that every character in t (including duplicates) is included in the window. If there is no such substring, return the empty string "".
#
# The testcases will be generated such that the answer is unique.
#
#
#
# Example 1:
#
# Input: s = "ADOBECODEBANC", t = "ABC"
# Output: "BANC"
# Explanation: The minimum window substring "BANC" includes 'A', 'B', and 'C' from string t.
# Example 2:
#
# Input: s = "a", t = "a"
# Output: "a"
# Explanation: The entire string s is the minimum window.
# Example 3:
#
# Input: s = "a", t = "aa"
# Output: ""
# Explanation: Both 'a's from t must be included in the window.
# Since the largest window of s only has one 'a', return empty string.
#
#
# Constraints:
#
# m == s.length
# n == t.length
# 1 <= m, n <= 105
# s and t consist of uppercase and lowercase English letters.
#
#
# Follow up: Could you find an algorithm that runs in O(m + n) time?

# %%
class Solution:
    def minWindow(self, s: str, t: str) -> str:
        if t=='':
            return ""
        # maintain two dict one for t and other for current window
        countT,window = {},{}

        for c in t:
            countT[c] = 1 + countT.get(c,0)
        # need = the elements required to be substrin eg: A:1,B:1,C:1
        # have = the elements we have in our current window
        have,need=0,len(countT)
        # res = the start and end of current window
        # res = size of the current window
        res, resLen = [-1,-1], float('inf')
        l=0

        for r in range(len(s)):
            c = s[r]
            window[c] = 1 + window.get(c,0)
            # if c in there in countT in only it matters 
            # and if we get the element the times we need it then increment have
            if c in countT and window[c]==countT[c]:
                have += 1
            # if the condition is met, try to reduce the size of the current window
            # via poping the window from the left side
            while need == have:
                #update the result
                if (r-l+1) < resLen:
                    res = [l,r]
                    resLen = r-l+1
                # pop the element from the left of the window
                window[s[l]] -= 1
                if s[l] in countT and window[s[l]]<countT[s[l]]:
                    have -= 1

                l+=1
        # store the start and end of the smallest window
        l, r = res

        return(s[l:r+1] if resLen != float('inf') else '' )
